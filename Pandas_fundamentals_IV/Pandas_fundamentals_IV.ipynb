# %%
import pandas as pd

df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Changing values in certain column.

# Set MSZoning for each row to value 1.
df.MSZoning = 1
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60         1         65.0     8450   Pave   NaN      Reg
# 1        2          20         1         80.0     9600   Pave   NaN      Reg
# 2        3          60         1         68.0    11250   Pave   NaN      IR1
# 3        4          70         1         60.0     9550   Pave   NaN      IR1
# 4        5          60         1         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60         1         62.0     7917   Pave   NaN      Reg
# 1456  1457          20         1         85.0    13175   Pave   NaN      Reg
# 1457  1458          70         1         66.0     9042   Pave   NaN      Reg
# 1458  1459          20         1         68.0     9717   Pave   NaN      Reg
# 1459  1460          20         1         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
list(range(0, 1460))  # The output is from 0 up to 1459.

# %%
# Set MSZoning for each row to values range(0, 1460) using array. 

df.MSZoning = list(range(0, 1460))
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60         0         65.0     8450   Pave   NaN      Reg
# 1        2          20         1         80.0     9600   Pave   NaN      Reg
# 2        3          60         2         68.0    11250   Pave   NaN      IR1
# 3        4          70         3         60.0     9550   Pave   NaN      IR1
# 4        5          60         4         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60      1455         62.0     7917   Pave   NaN      Reg
# 1456  1457          20      1456         85.0    13175   Pave   NaN      Reg
# 1457  1458          70      1457         66.0     9042   Pave   NaN      Reg
# 1458  1459          20      1458         68.0     9717   Pave   NaN      Reg
# 1459  1460          20      1459         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.Series(list(range(0, 1460)))
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1455    1455
# 1456    1456
# 1457    1457
# 1458    1458
# 1459    1459
# Length: 1460, dtype: int64

# %%
# Set MSZoning for each row to values range(0, 1460) using pandas Series. 

df.MSZoning = pd.Series(list(range(0, 1460)))
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60         0         65.0     8450   Pave   NaN      Reg
# 1        2          20         1         80.0     9600   Pave   NaN      Reg
# 2        3          60         2         68.0    11250   Pave   NaN      IR1
# 3        4          70         3         60.0     9550   Pave   NaN      IR1
# 4        5          60         4         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60      1455         62.0     7917   Pave   NaN      Reg
# 1456  1457          20      1456         85.0    13175   Pave   NaN      Reg
# 1457  1458          70      1457         66.0     9042   Pave   NaN      Reg
# 1458  1459          20      1458         68.0     9717   Pave   NaN      Reg
# 1459  1460          20      1459         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# When the length of pandas Series is different (pandas Series is shorter),  Python sets remaining values to Nan. 

df.MSZoning = pd.Series(list(range(0, 1458)))
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1        2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2        3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3        4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4        5          60       4.0         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60    1455.0         62.0     7917   Pave   NaN      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       NaN         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       NaN         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Printing row 1459.

df.iloc[1459]
# Out:
# Id                 1460
# MSSubClass           20
# MSZoning            NaN
# LotFrontage        75.0
# LotArea            9937
#                   ...
# MoSold                6
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        147500
# Name: 1459, Length: 81, dtype: object

# %%
# Printing row 1459 and column called MSZoning.

df.iloc[1459].MSZoning
# Out:
# nan

# %%
# Next chapter.
# Printing all rows where SalePrice is > 181500.

df[df.SalePrice > 181500]
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       0.0         65.0     8450   Pave   NaN      Reg
# 2        3          60       2.0         68.0    11250   Pave   NaN      IR1
# 4        5          60       4.0         84.0    14260   Pave   NaN      IR1
# 6        7          20       6.0         75.0    10084   Pave   NaN      Reg
# 7        8          60       7.0          NaN    10382   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1447  1448          60    1447.0         80.0    10000   Pave   NaN      Reg
# 1451  1452          20    1451.0         78.0     9262   Pave   NaN      Reg
# 1454  1455          20    1454.0         62.0     7500   Pave  Pave      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
# Working with copy of the dataframe. 

# Set for all SalePrice higher than 181500 to value 0.

df[df.SalePrice > 181500].SalePrice = 0
# Out:
# c:\users\janom\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df  # The original dataframe is not changed. (See SalePrice column.)
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1        2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2        3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3        4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4        5          60       4.0         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60    1455.0         62.0     7917   Pave   NaN      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       NaN         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       NaN         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Creating temporal dataframe temp_df.

temp_df = df[df.SalePrice > 181500]

# Changing values in temporal dataframe to 0.

temp_df.SalePrice = 0
# Out:
# c:\users\janom\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
temp_df  # Temporal dataframe is changed. (See SalePrice column.)
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       0.0         65.0     8450   Pave   NaN      Reg
# 2        3          60       2.0         68.0    11250   Pave   NaN      IR1
# 4        5          60       4.0         84.0    14260   Pave   NaN      IR1
# 6        7          20       6.0         75.0    10084   Pave   NaN      Reg
# 7        8          60       7.0          NaN    10382   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1447  1448          60    1447.0         80.0    10000   Pave   NaN      Reg
# 1451  1452          20    1451.0         78.0     9262   Pave   NaN      Reg
# 1454  1455          20    1454.0         62.0     7500   Pave  Pave      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
# Selecting rows and after that columns (in this order!!) using function loc.
# Set for all SalePrice higher than 181500 to value 0.

df.loc[df.SalePrice > 181500, "SalePrice"] = 0 
df  # Dataframe with changed values.
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1        2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2        3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3        4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4        5          60       4.0         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60    1455.0         62.0     7917   Pave   NaN      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       NaN         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       NaN         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Chaining conditions. This is a good way.
# : means all columns

df.loc[(df.SalePrice > 100000) & (df.MSSubClass > 30), :]
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       3.0         60.0     9550   Pave   NaN      IR1
# 5        6          50       5.0         85.0    14115   Pave   NaN      IR1
# 8        9          50       8.0         51.0     6120   Pave   NaN      Reg
# 9       10         190       9.0         50.0     7420   Pave   NaN      Reg
# 15      16          45      15.0         51.0     6120   Pave   NaN      Reg
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1445  1446          85    1445.0         70.0     8400   Pave   NaN      Reg
# 1448  1449          50    1448.0         70.0    11767   Pave   NaN      Reg
# 1450  1451          90    1450.0         60.0     9000   Pave   NaN      Reg
# 1452  1453         180    1452.0         35.0     3675   Pave   NaN      Reg
# 1455  1456          60    1455.0         62.0     7917   Pave   NaN      Reg
#
# ...
